# %%
T=20300
h=T//3600
r=T%3600
m=r//60
s=r%60
print(f"T: {T} est egale à {h}h {m}m {s}s")

# %%
#exercice 1
n = int(input("Entrez un nombre entier:"))
somme = 0
for i in range(1,n*2,2):
    somme+=i**2
print(f"la somme est {somme}")
